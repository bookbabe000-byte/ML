# %%
arr1=np.array([1,3,4])
arr2=np.array([4,6,7])
print(arr1+arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 arr1=np.array([1,3,4])
#       2 arr2=np.array([4,6,7])
#       3 print(arr1+arr2)
#
# NameError: name 'np' is not defined
